# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikita785/BLCMods/blob/master/PPDGAF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df_fd = pd.read_csv('/financial_data.csv')
df_pr = pd.read_csv('/prolongations.csv')

# %%
df_fd
# Out:
#       id        Причина дубля Ноябрь 2022 Декабрь 2022 Январь 2023  \
# 0     42                  NaN   36 220,00          NaN         NaN
# 1    657  первая часть оплаты        стоп          NaN         NaN
# 2    657  вторая часть оплаты        стоп          NaN         NaN
# 3    594                  NaN        стоп          NaN         NaN
# 4    665                  NaN   10 000,00          NaN         NaN
# ..   ...                  ...         ...          ...         ...
# 446  281      основные работы   76 550,00    79 950,00   66 900,00
# 447  281           доп работы   21 450,00    13 300,00   15 900,00
# 448  785                  NaN         NaN          NaN         NaN
# 449  913                  NaN         NaN          NaN         NaN
# 450  930  первая часть оплаты         NaN          NaN         NaN
#
#     Февраль 2023   Март 2023 Апрель 2023   Май 2023   Июнь 2023   Июль 2023  \
# 0            NaN         NaN         NaN        NaN         NaN         NaN
# ...

# %%
df_pr
# Out:
#        id         month                             AM
# 0      42   ноябрь 2022   Васильев Артем Александрович
# 1     453   ноябрь 2022   Васильев Артем Александрович
# 2     548   ноябрь 2022      Михайлов Андрей Сергеевич
# 3      87   ноябрь 2022  Соколова Анастасия Викторовна
# 4     429   ноябрь 2022  Соколова Анастасия Викторовна
# ..    ...           ...                            ...
# 472   955  декабрь 2023    Смирнова Ольга Владимировна
# 473  1004  декабрь 2023                        без А/М
# 474   281  декабрь 2023  Соколова Анастасия Викторовна
# 475   785  декабрь 2023  Соколова Анастасия Викторовна
# 476   913  декабрь 2023    Смирнова Ольга Владимировна
#
# [477 rows x 3 columns]

# %%
''' Шаг первый: очистка данных
   - Счел нужным удалить Причины дубля из df_fd для удобства
   - Преобразовать месяцы в df_fd в числовой тип и заполнить NaN нулями для реализации вычислений
'''
